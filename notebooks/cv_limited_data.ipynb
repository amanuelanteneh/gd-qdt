# %%
import sys
sys.path.extend(["../", "../src"])

# %%
from tqdm import tqdm
import numpy as np
from scipy.stats import poisson

import matplotlib
import matplotlib.pyplot as plt
import torch as th
from torch.utils.data import TensorDataset


from src.loss import phase_insensitive_loss_cvx
from src.gd_opt import learn_phase_insensitive_povm
from src.quantum import pnr_povm, diag_povm_fidelity, diag_mse_norm
from src.utils import check_diag_povm, find_lambda_max, square_normalize
from src.custom_types import Hyperparameters

matplotlib.rcParams.update({"font.size": 16})
plt.rcParams["figure.dpi"] = 125 #200  # set fig resolution
plt.rcParams.update({"text.usetex": True, "font.family": "Helvetica"})

seed = 42  # for reproducibility
th.manual_seed(seed);

# %%
M = 200
device = 'cpu'
N = 25
Ds = list(range(300, 2050, 90))
eta = 0.85
lam_smoothing = 1e-5
gd_trials = 20  # number of trials to average GD results over
avg_fids_gd_sample = []
avg_mses_gd_sample = []
avg_fids_mosek = []
avg_mses_mosek = []
iters_mosek = []
prob_norm_fn = "sqr"
batch_size = 25
# for low low data regime lr=0.1, lr_decay=0.99 and batch size 4 seems to work well
hyperparams = Hyperparameters(lr=0.01, lr_decay=0.999, beta1=0.9, beta2=0.9, num_epochs=100, batch_size=batch_size)

# %%
print(len(Ds))
# Out:
# 2

# %%
for D in tqdm(Ds, desc="Performing dataset experiments"):
    avg_fids_gd_M = []
    avg_mses_gd_M = []
    # PNR detector POVM
    true_povm = pnr_povm(hilbert_dim=M, N=N, eta=eta)
    true_povm = th.vstack( [th.diagonal(E) for E in true_povm] ).T

    max_avg = find_lambda_max(M, eps=1e-5)  # get max avg photon number for probes
    n_bars = np.linspace(0, max_avg, D)
    probes = th.tensor(np.array([ poisson.pmf(k=list(range(M)), mu=n_bar) for n_bar in n_bars ]), dtype=th.float32) 

    targets = probes @ true_povm  

    M, N, = probes.shape[1], targets.shape[1]
    
    probes = probes.to(device, dtype=th.float32)
    targets = targets.to(device)
    dataset = TensorDataset(probes, targets)

    for i in range(gd_trials):
        
        logits = th.rand((M, N)) - 1
        logits = logits.to(device)
        logits.requires_grad = True    
        
        logits, losses, _, _ = learn_phase_insensitive_povm(logits, hyperparams, dataset, lam_smoothing, False, None, 0, prob_norm_fn)

        if prob_norm_fn == "sqr":
            Pi = square_normalize(logits).to(device)  # rows are probability vectors so apply normalizaion along them
        else:    
            Pi = th.softmax(logits, dim=1).to(device)  # rows are probability vectors so apply softmax along them
        
        if check_diag_povm(Pi.T, tol=1e-5) is not True:
            print(f"WARNING: Gradient descent got invalid solution POVM for M={M}")

        Fs = [ diag_povm_fidelity(Pi[:, i], true_povm[:, i]) for i in range(true_povm.shape[1]) ]
        avg_fids_gd_M.append(sum(Fs)/len(Fs))

        mses = [ diag_mse_norm(Pi[:, i], true_povm[:, i]) for i in range(true_povm.shape[1]) ]
        avg_mses_gd_M.append(sum(mses)/len(mses))
    
    avg_fids_gd_sample.append(avg_fids_gd_M)
    avg_mses_gd_sample.append(avg_mses_gd_M)

    Pi, prob, iters = phase_insensitive_loss_cvx(targets.cpu().numpy(), probes.cpu().numpy(), lam_smoothing, "MOSEK")
    Pi = th.tensor(Pi)
    Fs = [ diag_povm_fidelity(Pi[:, i], true_povm[:, i]) for i in range(true_povm.shape[1]) ]
    avg_fids_mosek.append(sum(Fs)/len(Fs))

    mses = [ diag_mse_norm(Pi[:, i], true_povm[:, i]) for i in range(true_povm.shape[1]) ]
    avg_mses_mosek.append(sum(mses)/len(mses))

    iters_mosek.append(iters)
# Out:
# Performing dataset experiments: 100%|██████████| 2/2 [00:07<00:00,  3.89s/it]

# %%
arr = np.array(avg_fids_gd_sample)
mean = arr.mean(axis=1)
lower = mean - np.std(arr, axis=1)
upper = mean + np.std(arr, axis=1)

plt.plot(Ds, mean, color='C0', label=r'\textrm{Gradient Descent}', marker="o")
plt.fill_between(Ds, lower, upper, color='C0', alpha=0.3)

plt.plot(Ds, avg_fids_mosek, label=r'\textrm{CCO}', marker="o", color="darkorange")

plt.xlabel(r"\textrm{Number of probe states} $(D)$", fontsize=15.0)
plt.ylabel(r"$\bar{\mathcal{F}}$", fontsize=15.0)

plt.legend(fancybox=True, ncol=1, frameon=False);
# plt.yscale("log")
if eta < 1.0:
    plt.savefig("figs/lossy/lossy_data_fidelity.png", dpi=300, bbox_inches='tight')
else:
    plt.savefig("figs/ideal/ideal_data_fidelity.png", dpi=300, bbox_inches='tight')

# %%
arr = np.array(avg_mses_gd_sample)
mean = arr.mean(axis=1)
lower = mean - np.std(arr, axis=1)
upper = mean + np.std(arr, axis=1)

plt.plot(Ds, mean, color='C0', label=r'\textrm{Gradient Descent}', marker="o")
plt.fill_between(Ds, lower, upper, color='C0', alpha=0.3)

plt.plot(Ds, avg_mses_mosek, label=r'\textrm{CCO}', marker="o", color="darkorange")

plt.xlabel(r"\textrm{Number of probe states} $(D)$", fontsize=15.0)
plt.ylabel(r"$\textrm{Average MSE}$", fontsize=17.0)

plt.yscale("log")
plt.legend(fancybox=True, ncol=1, frameon=False);

if eta < 1.0:
    plt.savefig("figs/lossy/lossy_data_mse.png", dpi=300, bbox_inches='tight')
else:
    plt.savefig("figs/ideal/ideal_data_mse.png", dpi=300, bbox_inches='tight')

# %%
plt.plot(Ds, iters_mosek, label=r'\textrm{CCO}', marker="o", color="darkorange")
plt.xlabel(r"\textrm{Number of probe states} $(D)$", fontsize=15.0)
plt.ylabel(r"$\textrm{Number of iterations}$", fontsize=15.0)
plt.legend(fancybox=True, ncol=1, frameon=False);
if eta < 1.0:
    plt.savefig("figs/lossy/lossy_data_iters.png", dpi=300, bbox_inches='tight')
else:
    plt.savefig("figs/ideal/ideal_data_iters.png", dpi=300, bbox_inches='tight')
